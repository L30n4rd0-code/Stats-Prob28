# %%
import time
mood = int(input("From one to ten how are you feeling today? ")) #Please answer this question with a value lower or equal to 7
if mood <= 7:
    print("Come on, cheer up a little bit")
else:
    print("Perfect, you are the most dope guy")
    
plan = input("Do you want me to cheer you up? ")

if plan == "yes": #Try to pick this, for a longer conversation
    print("Well, let me try a few things...")
    
    animal = input("Do you like cats or dogs? ")
    
    if animal == "cats":
        print("I will show you some kitties pictures")
    elif animal == "dogs":
        print("Let's see some funny dogs videos")
    time.sleep(5)
    
    was = input("That was fun was not?  ")

    if was == "yes":
        print("Perfect, that makes me feel happier")
    elif was == "no": #Try to pick this, for a longer conversation
        print("But animals are cute, anyway, let me try with another thing")
        time.sleep(5)
    
        music = input("""
        Let\'s listen some music, do you prefer to: 
        1. Listen your favorite songs  
        2. Ask for recommendations 
        Write \'favorites\' or \'recommendations\' to choose an option """)
        
        if music == "favorites":
            print("Now we are rocking boy")
        
        elif music == "recommendations":
            print("""Some cool boy told me that these are very nice music groups:
            \a The Killers
            \a Lord Huron
            \a Blink 182
            \a Twenty One Pilots
            \a Division Minuscula""")
        
        group = input("Which group do you want to listen? ") #Write it correctly to avoid errors

        print("You could try these songs:")
        if group == "The Killers":
            print(""" 
            \a The Man
            \a Human
            \a Spaceman
            \a Deadlines and commitment
            Very motivating lyrics and enjoyable melodies""")
        elif group == "Lord Huron":
            print("""
            \a Meet me in the woods
            \a The man who live forever
            \a When the night is over
            \a Fool for love
            Folk songs, to be within the woods""")
        elif group == "Blink 182":
            print("""
            \a Always
            \a Josie
            \a Dammit
            \a First Date""")
        elif group == "Twenty One Pilots":
            print("""
            \a Legend
            \a Semi-Automatic
            \a Ode to sleep""")
        elif group == "Division Minuscula":
            print("""
            \a Maquillaje
            \a Gracias
            \a Sognare""")
        else:
            print("Unfortunately I don\'t know that band'")
        print("I hope your day gets better with some music guy")
    
else:
    print("Hum, with that attitude nothing will change")
# Out:
# From one to ten how are you feeling today? 5
# Come on, cheer up a little bit
# Do you want me to cheer you up? yes
# Well, let me try a few things...
# Do you like cats or dogs? cats
# I will show you some kitties pictures
# That was fun was not?  no
# But animals are cute, anyway, let me try with another thing
#
#         Let's listen some music, do you prefer to:
#         1. Listen your favorite songs
#         2. Ask for recommendations
#         Write 'favorites' or 'recommendations' to choose an option recommendations
# Some cool boy told me that these are very nice music groups:
#              The Killers
#              Lord Huron
#              Blink 182
#              Twenty One Pilots
#              Division Minuscula
# Which group do you want to listen? The Killers
# You could try these songs:
#
#              The Man
#              Human
#              Spaceman
#              Deadlines and commitment
#             Very motivating lyrics and enjoyable melodies
# ...
